# %%
import os
import joblib

# Cell 0: carregar modelo

model_path = 'modelo/random_forest.joblib'
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Arquivo não encontrado: {model_path}")

model = joblib.load(model_path)
print(f"Modelo carregado de: {model_path}")
# Out:
# Modelo carregado de: modelo/random_forest.joblib

# %%
print("Top 3 variáveis com maior importância no modelo:")
for feature, importance in zip(top3_features, top3_importances):
    print(f"{feature}: {importance:.6f}")
# Out:
# Top 3 variáveis com maior importância no modelo:
# Bwd Packets/s: 0.042822
# Flow IAT Mean: 0.042535
# Flow IAT Std: 0.041910
